# %%
pip install pymongo
# Out:
# ...
#   Using cached dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/484.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/484.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/484.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/484.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/484.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/484.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/484.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/484.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/484.1 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/484.1 kB ? eta -:--:--
#    ---------------------------------------- 484.1/484.1 kB 7.5 MB/s eta 0:00:00
# Using cached dnspython-2.6.1-py3-none-any.whl (307 kB)
# ...

# %%
import pymongo
from pymongo import MongoClient
