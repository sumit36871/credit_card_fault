# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\projects\credit_card_fault\card\lib\site-packages (4.8.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\projects\credit_card_fault\card\lib\site-packages (from pymongo) (2.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
from pymongo import MongoClient

# %%
connection_string = "mongodb+srv://credit_card:1234@cluster0.e5ctatl.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
client = MongoClient(connection_string)

# %%
db = client["credit_test"]

# %%
collection = db["mongoclass"]

# %%
data = {
    "name" : "sumit yadav",
    "age" : 2,
    "email": "sumitbsc36871@gmail.com"
}

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('66abb2b66c0ec7955f60d0ae'), acknowledged=True)

# %%
cursor = collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('66abb2b66c0ec7955f60d0ae'), 'name': 'sumit yadav', 'age': 2, 'email': 'sumitbsc36871@gmail.com'}
